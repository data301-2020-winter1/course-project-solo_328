# %% [markdown]
# # **Project Functions**

# %% [markdown]
# #### *This notebook contains useful functions for the DATA 301 project*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Function to load and process data

# %%
def load_and_process(url_or_path_to_csv_file):
    df1 = (
        pd.read_csv(url_or_path_to_csv_file)
          .dropna()
          .reset_index(drop=True)
    )
    df2 = (
        df1.loc[lambda x: ~df1['title'].str.contains('Deleted video')]
        .drop(columns = ["video_id", "description", "ratings_disabled", "tags", "comments_disabled", "thumbnail_link"])
    )
    

    df3 = df2[df2['video_error_or_removed'] == False].drop(columns = ["video_error_or_removed"])
    
    return df3

# %%
CA_YT = load_and_process(r"C:\Data\UBCO\DATA 301\Project\course-project-solo_328\data\raw\Youtube_data\CAvideos.csv")
CA_YT
# Out:
#       trending_date                                              title  \
# 0          17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1          17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                           I Dare You: GOING BALD!?
# 4          17.14.11        Ed Sheeran - Perfect (Official Music Video)
# ...             ...                                                ...
# 39580      18.14.06                       HOW2: How to Solve a Mystery
# 39581      18.14.06                   Eli Lik Lik Episode 13 Partie 01
# 39582      18.14.06  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...
# 39583      18.14.06                   Trump Advisor Grovels To Trudeau
# 39584      18.14.06                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班
#
#           channel_title  category_id              publish_time     views  \
# ...

# %%
import datetime

Time = CA_YT['publish_time'].values[0]
print(Time)
print(datetime.datetime.strptime(Time, "%Y-%b-%dT%H:%M:%S.%fZ"))
# Out:
# 2017-11-10T17:00:03.000Z
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-7010843e5390> in <module>
#       3 Time = CA_YT['publish_time'].values[0]
#       4 print(Time)
# ----> 5 print(datetime.datetime.strptime(Time, "%Y-%b-%dT%H:%M:%S.%fZ"))
#
# ~\miniconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~\miniconda3\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
# ...

# %%
#def load_and_process(path_to_csv):
   
    df1 = (pd.read_csv(path_to_csv)
           .rename(columns={"publish_time": "Publish_dt"}
           .dropna())
           
    df2 = (df1.drop(columns=['video_id', 'thumbnail_link', 'ratings_disabled' 'video_error_or_removed']))
           
    return df2
# Out:
#   File "<ipython-input-27-e3f1b584d301>", line 3
#     df1 = (pd.read_csv(path_to_csv)
#     ^
# IndentationError: unexpected indent
